# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
data = pd.read_csv('C:/Users/USER/Desktop/africa_food_prices.csv',index_col =0) # To import the file
data.head()
# Out:
#        country_id  country  state_id  state  market_id   market  produce_id  \
# 15427         4.0  Algeria       344  Alger       1794  Algiers          52
# 15428         4.0  Algeria       344  Alger       1794  Algiers          52
# 15429         4.0  Algeria       344  Alger       1794  Algiers          52
# 15430         4.0  Algeria       344  Alger       1794  Algiers          52
# 15431         4.0  Algeria       344  Alger       1794  Algiers          52
#
#              produce  currency_id currency  pt_id market_type  um_unit_id  \
# 15427  Rice - Retail          0.0      DZD     15      Retail           5
# 15428  Rice - Retail          0.0      DZD     15      Retail           5
# 15429  Rice - Retail          0.0      DZD     15      Retail           5
# 15430  Rice - Retail          0.0      DZD     15      Retail           5
# 15431  Rice - Retail          0.0      DZD     15      Retail           5
#
#       quantity  month  year  price  mp_commoditysource
# ...

# %%
data.tail()
# Out:
#          country_id   country  state_id     state  market_id      market  \
# 2050633       271.0  Zimbabwe      3444  Midlands       5594  Mbilashaba
# 2050634       271.0  Zimbabwe      3444  Midlands       5594  Mbilashaba
# 2050635       271.0  Zimbabwe      3444  Midlands       5594  Mbilashaba
# 2050636       271.0  Zimbabwe      3444  Midlands       5594  Mbilashaba
# 2050637       271.0  Zimbabwe      3444  Midlands       5594  Mbilashaba
#
#          produce_id                  produce  currency_id currency  pt_id  \
# 2050633         432   Beans (sugar) - Retail          0.0      ZWL     15
# 2050634         539      Toothpaste - Retail          0.0      ZWL     15
# 2050635         540    Laundry soap - Retail          0.0      ZWL     15
# 2050636         541   Handwash soap - Retail          0.0      ZWL     15
# 2050637         887  Fish (kapenta) - Retail          0.0      ZWL     15
#
#         market_type  um_unit_id quantity  month  year      price  \
# ...

# %%
data.describe()
# Out:
#           country_id       state_id      market_id     produce_id  \
# count  956779.000000  956779.000000  956779.000000  956779.000000
# mean     1961.192782   22287.911831    1392.594222     186.141214
# std     10404.034921   98565.608270    1027.751212     165.401303
# min         4.000000       0.000000     101.000000      50.000000
# 25%        90.000000    1836.000000     528.000000      67.000000
# 50%       155.000000    2209.000000    1078.000000     105.000000
# 75%       205.000000   21971.000000    2281.000000     262.000000
# max     70001.000000  900003.000000    6081.000000     887.000000
#
#        currency_id          pt_id     um_unit_id          month  \
# count     956779.0  956779.000000  956779.000000  956779.000000
# mean           0.0      14.926716      14.017183       6.381471
# std            0.0       0.263570      24.437728       3.418025
# min            0.0      14.000000       5.000000       1.000000
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 956779 entries, 15427 to 2050637
# Data columns (total 18 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   country_id          956779 non-null  float64
#  1   country             956779 non-null  object
#  2   state_id            956779 non-null  int64
#  3   state               830101 non-null  object
#  4   market_id           956779 non-null  int64
#  5   market              956779 non-null  object
#  6   produce_id          956779 non-null  int64
#  7   produce             956779 non-null  object
#  8   currency_id         956779 non-null  float64
#  9   currency            956779 non-null  object
#  10  pt_id               956779 non-null  int64
#  11  market_type         956779 non-null  object
#  12  um_unit_id          956779 non-null  int64
#  13  quantity            956779 non-null  object
#  14  month               956779 non-null  int64
# ...

# %% [markdown]
# # checking number of blank space

# %%
data.isna().sum()
# Out:
# country_id                 0
# country                    0
# state_id                   0
# state                 126678
# market_id                  0
# market                     0
# produce_id                 0
# produce                    0
# currency_id                0
# currency                   0
# pt_id                      0
# market_type                0
# um_unit_id                 0
# quantity                   0
# month                      0
# year                       0
# price                      0
# mp_commoditysource    956779
# dtype: int64

# %%
# To check for the various Data types in the file
type=data.dtypes
print(type)
# Out:
# country_id            float64
# country                object
# state_id                int64
# state                  object
# market_id               int64
# market                 object
# produce_id              int64
# produce                object
# currency_id           float64
# currency               object
# pt_id                   int64
# market_type            object
# um_unit_id              int64
# quantity               object
# month                   int64
# year                    int64
# price                 float64
# mp_commoditysource    float64
# dtype: object

# %%
data
# Out:
#          country_id   country  state_id     state  market_id      market  \
# 15427           4.0   Algeria       344     Alger       1794     Algiers
# 15428           4.0   Algeria       344     Alger       1794     Algiers
# 15429           4.0   Algeria       344     Alger       1794     Algiers
# 15430           4.0   Algeria       344     Alger       1794     Algiers
# 15431           4.0   Algeria       344     Alger       1794     Algiers
# ...             ...       ...       ...       ...        ...         ...
# 2050633       271.0  Zimbabwe      3444  Midlands       5594  Mbilashaba
# 2050634       271.0  Zimbabwe      3444  Midlands       5594  Mbilashaba
# 2050635       271.0  Zimbabwe      3444  Midlands       5594  Mbilashaba
# 2050636       271.0  Zimbabwe      3444  Midlands       5594  Mbilashaba
# 2050637       271.0  Zimbabwe      3444  Midlands       5594  Mbilashaba
#
#          produce_id                  produce  currency_id currency  pt_id  \
# ...

# %% [markdown]
# ### Dropping all rows with blank values

# %%
datano = data.dropna(thresh=len(data.columns)-1)

# %%
datano.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 830101 entries, 15427 to 2050637
# Data columns (total 18 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   country_id          830101 non-null  float64
#  1   country             830101 non-null  object
#  2   state_id            830101 non-null  int64
#  3   state               830101 non-null  object
#  4   market_id           830101 non-null  int64
#  5   market              830101 non-null  object
#  6   produce_id          830101 non-null  int64
#  7   produce             830101 non-null  object
#  8   currency_id         830101 non-null  float64
#  9   currency            830101 non-null  object
#  10  pt_id               830101 non-null  int64
#  11  market_type         830101 non-null  object
#  12  um_unit_id          830101 non-null  int64
#  13  quantity            830101 non-null  object
#  14  month               830101 non-null  int64
# ...

# %%
datano.describe()
# Out:
#           country_id       state_id      market_id     produce_id  \
# count  830101.000000  830101.000000  830101.000000  830101.000000
# mean      632.649091   25113.438302    1378.159070     178.594207
# std      4407.314078  105511.459114    1030.335027     163.782597
# min         4.000000     344.000000     124.000000      50.000000
# 25%        90.000000    1816.000000     554.000000      66.000000
# 50%       155.000000    2230.000000    1070.000000      97.000000
# 75%       205.000000   21971.000000    2027.000000     254.000000
# max     40764.000000  900003.000000    5594.000000     887.000000
#
#        currency_id          pt_id     um_unit_id          month  \
# count     830101.0  830101.000000  830101.000000  830101.000000
# mean           0.0      14.917557      12.658383       6.391578
# std            0.0       0.278278      22.626311       3.418432
# min            0.0      14.000000       5.000000       1.000000
# ...

# %%
datano.isna().sum()
# Out:
# country_id                 0
# country                    0
# state_id                   0
# state                      0
# market_id                  0
# market                     0
# produce_id                 0
# produce                    0
# currency_id                0
# currency                   0
# pt_id                      0
# market_type                0
# um_unit_id                 0
# quantity                   0
# month                      0
# year                       0
# price                      0
# mp_commoditysource    830101
# dtype: int64

# %% [markdown]
# # dropping the last column will all value NAN

# %%
datanon=datano.iloc[: , 0: 17]
datanon
# Out:
#          country_id   country  state_id     state  market_id      market  \
# 15427           4.0   Algeria       344     Alger       1794     Algiers
# 15428           4.0   Algeria       344     Alger       1794     Algiers
# 15429           4.0   Algeria       344     Alger       1794     Algiers
# 15430           4.0   Algeria       344     Alger       1794     Algiers
# 15431           4.0   Algeria       344     Alger       1794     Algiers
# ...             ...       ...       ...       ...        ...         ...
# 2050633       271.0  Zimbabwe      3444  Midlands       5594  Mbilashaba
# 2050634       271.0  Zimbabwe      3444  Midlands       5594  Mbilashaba
# 2050635       271.0  Zimbabwe      3444  Midlands       5594  Mbilashaba
# 2050636       271.0  Zimbabwe      3444  Midlands       5594  Mbilashaba
# 2050637       271.0  Zimbabwe      3444  Midlands       5594  Mbilashaba
#
#          produce_id                  produce  currency_id currency  pt_id  \
# ...

# %% [markdown]
# # Confirming that no more blank value

# %%
datanon.isna().sum()
# Out:
# country_id     0
# country        0
# state_id       0
# state          0
# market_id      0
# market         0
# produce_id     0
# produce        0
# currency_id    0
# currency       0
# pt_id          0
# market_type    0
# um_unit_id     0
# quantity       0
# month          0
# year           0
# price          0
# dtype: int64

# %% [markdown]
# # Suming the column value by produce

# %%
dfproduce=datanon.groupby('produce').sum()

dfproduce
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_6180\3740173389.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   dfproduce=datanon.groupby('produce').sum()
#                              country_id  state_id  market_id  produce_id  \
# produce
# Apples (red) - Retail          212815.0  32518012    1315243      342813
# Apples - Retail                   320.0     30016     145346       27600
# Avocados - Retail              504707.0  88899801    4843111     1508642
# Bananas (imported) - Retail      1575.0     20862      38113       12045
# Bananas (local) - Retail        41895.0    554325    1623641      282093
# ...                                 ...       ...        ...         ...
# Yam (yellow) - Retail            1856.0     39315     140110       48832
# ...

# %% [markdown]
# # Displaying the top 10 highest price

# %%
datatop=datanon.nlargest(n=10, columns=['price'])
datatop
# Out:
#          country_id  country  state_id  state  market_id     market  \
# 1647877       226.0  Somalia      2700  Mudug       1417  Gaalkacyo
# 1647885       226.0  Somalia      2700  Mudug       1417  Gaalkacyo
# 1647878       226.0  Somalia      2700  Mudug       1417  Gaalkacyo
# 1647879       226.0  Somalia      2700  Mudug       1417  Gaalkacyo
# 1647880       226.0  Somalia      2700  Mudug       1417  Gaalkacyo
# 1647881       226.0  Somalia      2700  Mudug       1417  Gaalkacyo
# 1647882       226.0  Somalia      2700  Mudug       1417  Gaalkacyo
# 1647883       226.0  Somalia      2700  Mudug       1417  Gaalkacyo
# 1647884       226.0  Somalia      2700  Mudug       1417  Gaalkacyo
# 1647886       226.0  Somalia      2700  Mudug       1417  Gaalkacyo
#
#          produce_id                produce  currency_id currency  pt_id  \
# 1647877         344  Meat (camel) - Retail          0.0      SOS     15
# 1647885         344  Meat (camel) - Retail          0.0      SOS     15
# ...

# %%
sn=sns.barplot(x="year", y="price", data=datatop)
sn
# Out:
# <AxesSubplot: xlabel='year', ylabel='price'>

# %%
sn=sns.barplot(x="year", y="price", data=datanon)
sn
# Out:
# <AxesSubplot: xlabel='year', ylabel='price'>

# %%
# To group based on the produce
dataprod = data.groupby('produce')

# %%
dataprod.count()
# Out:
#                              country_id  country  state_id  state  market_id  \
# produce
# Apples (red) - Retail              1497     1497      1497   1497       1497
# Apples - Retail                      80       80        80     80         80
# Avocados - Retail                  3323     3323      3323   3323       3323
# Bananas (imported) - Retail          15       15        15     15         15
# Bananas (local) - Retail            399      399       399    399        399
# ...                                 ...      ...       ...    ...        ...
# Yam (yellow) - Retail                64       64        64     64         64
# Yam - Retail                       3037     3037      3037   3037       3037
# Yam - Wholesale                    2670     2670      2670   2670       2670
# Yogurt - Retail                     240      240       240    240        240
# Zucchini - Retail                  1523     1523      1523   1523       1523
#
# ...
